# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

from utils import key2word, key2ruword


fg_file = "../data/in_data/fg_R9_manifest.tsv"
mapping_file = "../data/in_data/fg_R9_ukb_mapping.tsv"
ukb_file = "../data/in_data/panukb_phenotype_manifest.csv"
ukb_neale_file = "../data/in_data/ukb_manifest.csv"

merged_to = "../data/merged_bio.tsv"
codes_to = "../data/codes.tsv"

# %%
fg_cols = ['phenocode', 'name', 'category']
mapping_cols = ['name', 'category', 'fg_phenotype', 'ukbb_phenotype']
ukb_cols = ['phenocode', 'description', "description_more"]

# %%
# read
fg = pd.read_csv(fg_file, sep='\t')[fg_cols].drop_duplicates(keep='first')
ukb = pd.read_csv(ukb_file, sep=',')[ukb_cols].drop_duplicates(keep='first')
# neale = pd.read_csv(ukb_neale_file, sep=',')
mapping = pd.read_csv(mapping_file, sep='\t')[mapping_cols].drop_duplicates(keep='first')




display(fg.head())
display(ukb.head())
# display(neale.head())
display(mapping.head())
print(fg.shape, ukb.shape, mapping.shape)
# Out:
#                        phenocode  \
# 0              AB1_ACTINOMYCOSIS
# 1                 AB1_AMOEBIASIS
# 2  AB1_ANOGENITAL_HERPES_SIMPLEX
# 3              AB1_ASPERGILLOSIS
# 4         AB1_ATYPICAL_CNS_VIRUS
#
#                                                 name  \
# 0                                      Actinomycosis
# 1                                         Amoebiasis
# 2  Anogenital herpesviral [herpes simplex] infection
# 3                                      Aspergillosis
# 4  Atypical virus infections of central nervous s...
#
#                                             category
# 0  I Certain infectious and parasitic diseases (A...
# 1  I Certain infectious and parasitic diseases (A...
# 2  I Certain infectious and parasitic diseases (A...
# 3  I Certain infectious and parasitic diseases (A...
# 4  I Certain infectious and parasitic diseases (A...
#   phenocode               description description_more
# 0     30600                   Albumin              NaN
# 1     30610      Alkaline phosphatase              NaN
# 2     30620  Alanine aminotransferase              NaN
# 3     30630          Apolipoprotein A              NaN
# 4     30640          Apolipoprotein B              NaN
#                                                 name  \
# 0                                      Aspergillosis
# 1                                        Candidiasis
# 2                                    Dermatophytosis
# 3  Diarrhoea and gastroenteritis of presumed infe...
# 4                                      Helminthiases
#
#                                             category             fg_phenotype  \
# 0  I Certain infectious and parasitic diseases (A...        AB1_ASPERGILLOSIS
# 1  I Certain infectious and parasitic diseases (A...          AB1_CANDIDIASIS
# 2  I Certain infectious and parasitic diseases (A...      AB1_DERMATOPHYTOSIS
# 3  I Certain infectious and parasitic diseases (A...  AB1_GASTROENTERITIS_NOS
# 4  I Certain infectious and parasitic diseases (A...         AB1_HELMINTIASES
#
#   ukbb_phenotype
# 0            B44
# 1            B37
# 2            B35
# 3            A09
# 4            134
# (2272, 3) (3925, 3) (679, 4)

# %% [markdown]
# Проверим множества

# %%
mapping.fg_phenotype.unique().shape, mapping.ukbb_phenotype.unique().shape
# Out:
# ((679,), (657,))

# %% [markdown]
# Получается буквально несколько юкбишных дублируются. Ок

# %% [markdown]
# ## Мержим

# %%
def merge_columns(df, col1, col2):
    """
    Merge two columns in a DataFrame based on specified rules.
    - If values are equal, pick that one.
    - If one is NaN, pick the other.
    - If they are not equal, concatenate them into a string.
    """
    def merge_row(row):
        if row[col1] == row[col2]:
            return row[col1]
        elif pd.isna(row[col1]):
            return row[col2]
        elif pd.isna(row[col2]):
            return row[col1]
        else:
            return str(row[col1]) + " " + str(row[col2])

    return df.apply(merge_row, axis=1)

# %%
merged = ukb.add_suffix('_ukb').merge(
    mapping.add_suffix('_meta'), 
    how='outer', 
    left_on='phenocode_ukb', 
    right_on='ukbb_phenotype_meta',
).rename(columns={"fg_phenotype_meta":"fg_phenotype", "ukbb_phenotype_meta": "ukbb_phenotype"}).merge(
    fg.add_suffix('_fg'), 
    how='outer', 
    left_on='fg_phenotype', 
    right_on='phenocode_fg',
)

merged['ukb_code'] = merge_columns(merged, 'phenocode_ukb', 'ukbb_phenotype')
merged['fg_code'] = merge_columns(merged, 'fg_phenotype', 'phenocode_fg')
merged['fg_name'] = merge_columns(merged, 'name_meta',  'name_fg')

merged = merged[['ukb_code', 'fg_code', 'fg_name', 'category_fg', 'category_meta', 'description_ukb', 'description_more_ukb']]
merged.sample(5)
# Out:
#      ukb_code                   fg_code                               fg_name  \
# 99       2000                       NaN                                   NaN
# 5222      NaN        M13_HALLUDEFORMOTH  Other deformity of hallux (acquired)
# 2380    495.2                       NaN                                   NaN
# 2180    348.8                       NaN                                   NaN
# 3602      O62  O15_LABOUR_ABNORM_FORCES     Abnormalities of forces of labour
#
#                                             category_fg  \
# 99                                                  NaN
# 5222  XIII Diseases of the musculoskeletal system an...
# 2380                                                NaN
# 2180                                                NaN
# 3602  XV Pregnancy, childbirth and the puerperium (O...
#
#                                           category_meta  \
# 99                                                  NaN
# 5222                                                NaN
# 2380                                                NaN
# 2180                                                NaN
# 3602  XV Pregnancy, childbirth and the puerperium (O...
#
#                                description_ukb  \
# 99          Worry too long after embarrassment
# 5222                                       NaN
# 2380                  Asthma with exacerbation
# 2180  Encephalopathy, not elsewhere classified
# 3602     O62 Abnormalities of forces of labour
#
#                                    description_more_ukb
# 99    ACE touchscreen question "Do you worry too lon...
# 5222                                                NaN
# 2380                                                NaN
# 2180                                                NaN
# 3602                                    truncated: true

# %% [markdown]
# Все, теперь сохраним, так как будем этим пользоваться.

# %%
merged.to_csv(merged_to, sep='\t', index=False)

# %% [markdown]
# ## Коды нашего биобанка

# %%
ru_en_names = pd.DataFrame([key2word, key2ruword]).T
ru_en_names.columns = ['en', 'ru']
ru_en_names = ru_en_names.reset_index().rename(columns={'index':'codes'})
ru_en_names
# Out:
#                    codes                                     en  \
# 0               type_днк                                    DNA
# 1               type_инг          Whole blood in RNA stabilizer
# 2              type_моча                                  Urine
# 3                type_пл                                 Plasma
# 4            type_пл(фф)                Plasma (fetal fraction)
# 5              type_плац                               Placenta
# 6           type_пуп_инг           Cord blood in RNA stabilizer
# 7           type_пуп_лей                  Cord blood buffy coat
# 8            type_пуп_пл                      Cord blood plasma
# 9           type_пуп_сыв                       Cord blood serum
# 10              type_пуп                             Cord blood
# 11               type_цк                            Whole blood
# 12              type_лей                             Buffy coat
# 13              type_сыв                                  Serum
# 14               type_пк                      Dried blood spots
# 15              type_эяк                                  Semen
# 16              type_рнк                                    RNA
# 17             type_пркл           Fixed somatic and germ cells
# 18              type_спл                         Seminal plasma
# 19               type_гд               Gonadal biopsy specimens
# 20               type_лп                         Leukocyte film
# 21  collection_monogenic                     Monogenic diseases
# 22    collection_obs_gyn  Obstetric and gynecologic pathologies
# 23      collection_multi                Multifactorial diseases
# 24        collection_pop                     Population control
# 25       collection_spon                   Spontaneous abortion
# 26     collection_infert                            Infertility
# 27  collection_repro_dis            Reproductive system disease
# 28    collection_sex_vio           Disorders of sex development
#
#                                                    ru
# 0                                                 ДНК
# 1   Цельная кровь в консерванте для для стабилизац...
# 2                                                Моча
# 3                                              Плазма
# 4                          Плазма (фетальная фракция)
# 5                                            Плацента
# 6   Пуповинная кровь в консерванте для стабилизаци...
# 7            Лейкоцитарная пленка из пуповинной крови
# 8                             Плазма пуповинной крови
# 9                          Сыворотка пуповинной крови
# 10                                   Пуповинная кровь
# 11                                      Цельная кровь
# 12                               Лейкоцитарная пленка
# 13                                    Сыворотка крови
# 14                                        Пятна крови
# 15                                            Эякулят
# 16                                                РНК
# 17  Зафиксированные препараты соматических и полов...
# 18                                    Семенная плазма
# 19                                     Биоптаты гонад
# 20                               Лейкоцитарная плёнка
# 21                             Моногенные заболевания
# 22            Акушерские и гинекологические патологии
# 23                        Мультифакторные заболевания
# 24                             Популяционный контроль
# 25                 Спонтанное прерывание беременности
# 26                                          Бесплодие
# 27                   Нарушение репродуктивной системы
# 28                        Нарушение формирования пола

# %%
ru_en_names.to_csv(codes_to, sep='\t', index=False)
